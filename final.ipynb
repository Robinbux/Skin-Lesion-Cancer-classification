# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers.legacy import Adam

from data.data_generator import ColorSpace, SkinLesionDataSequence, DatasetType

# %% [markdown]
# ## Load and Visualize the Data

# %%
def display_images_for_color_space(color_space):
    data_sequence = SkinLesionDataSequence(base_dir='data', dataset_type=DatasetType.Train, color_space=color_space, batch_size=2, normalize=False)
    
    images, _ = data_sequence[0]
    
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    for i, img in enumerate(images):
        if color_space != ColorSpace.Greyscale:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)        
        axes[i].imshow(img)
        axes[i].axis('off')
        axes[i].set_title(f'{color_space.value} Image {i+1}')
    plt.show()

for color_space in ColorSpace:
    display_images_for_color_space(color_space)

# %% [markdown]
# ## Preprocess the Images
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9324455/
#
# \begin{equation}
# I_{\text {norm }}=\left(I-\operatorname{Min}_I\right)\left(\frac{2}{\operatorname{Max}_I-\operatorname{Min}_I}\right)-1
# \end{equation}

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

def build_model(input_shape=(224, 224, 3)):
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    return model

batch_size = 32
epochs = 10

for color_space in ColorSpace:
    print(f"Training model for {color_space.value} color space...")
    
    input_shape = (224, 224, 3)  
    model = build_model(input_shape=input_shape)
    
    checkpoint_filepath = f'best_model_{color_space.value}.keras'
    model_checkpoint_callback = ModelCheckpoint(filepath=checkpoint_filepath, save_best_only=True, monitor='val_accuracy', mode='max')
    
    train_sequence = SkinLesionDataSequence(base_dir='data', dataset_type=DatasetType.Train, color_space=color_space, batch_size=batch_size, normalize=True)
    val_sequence = SkinLesionDataSequence(base_dir='data', dataset_type=DatasetType.Validation, color_space=color_space, batch_size=batch_size, normalize=True)
    
    # Train the model
    model.fit(train_sequence, epochs=epochs, validation_data=val_sequence, callbacks=[model_checkpoint_callback])
    
    print(f"Best model for {color_space.value} color space saved as {checkpoint_filepath}")
# Out:
# Training model for BGR color space...
# Epoch 1/10
# 372/372 [==============================] - 146s 393ms/step - loss: 0.5914 - accuracy: 0.7643 - val_loss: 0.4665 - val_accuracy: 0.7575
# Epoch 2/10
# 372/372 [==============================] - 153s 411ms/step - loss: 0.4401 - accuracy: 0.8065 - val_loss: 0.3727 - val_accuracy: 0.8300
# Epoch 3/10
# 372/372 [==============================] - 149s 399ms/step - loss: 0.3686 - accuracy: 0.8305 - val_loss: 1.3786 - val_accuracy: 0.6575
# Epoch 4/10
# 372/372 [==============================] - 146s 392ms/step - loss: 0.4245 - accuracy: 0.8242 - val_loss: 0.4144 - val_accuracy: 0.7900
# Epoch 5/10
# 372/372 [==============================] - 146s 393ms/step - loss: 0.3462 - accuracy: 0.8459 - val_loss: 0.3146 - val_accuracy: 0.8875
# Epoch 6/10
# 372/372 [==============================] - 147s 396ms/step - loss: 0.3250 - accuracy: 0.8513 - val_loss: 0.2951 - val_accuracy: 0.8625
# Epoch 7/10
# 372/372 [==============================] - 145s 390ms/step - loss: 0.2881 - accuracy: 0.8714 - val_loss: 0.2753 - val_accuracy: 0.8925
# Epoch 8/10
# 372/372 [==============================] - 145s 389ms/step - loss: 0.2610 - accuracy: 0.8848 - val_loss: 0.2820 - val_accuracy: 0.8825
# Epoch 9/10
# 372/372 [==============================] - 146s 392ms/step - loss: 0.2375 - accuracy: 0.8938 - val_loss: 0.2676 - val_accuracy: 0.8875
# Epoch 10/10
# 372/372 [==============================] - 145s 389ms/step - loss: 0.2067 - accuracy: 0.9098 - val_loss: 0.2949 - val_accuracy: 0.9075
# Best model for BGR color space saved as best_model_BGR.keras
# Training model for HSV color space...
# Epoch 1/10
# 372/372 [==============================] - 146s 391ms/step - loss: 0.6304 - accuracy: 0.7813 - val_loss: 0.3435 - val_accuracy: 0.8500
# Epoch 2/10
# 372/372 [==============================] - 147s 396ms/step - loss: 0.3813 - accuracy: 0.8326 - val_loss: 0.3620 - val_accuracy: 0.8650
# Epoch 3/10
# 372/372 [==============================] - 155s 413ms/step - loss: 0.3729 - accuracy: 0.8427 - val_loss: 0.4526 - val_accuracy: 0.7850
# Epoch 4/10
# 372/372 [==============================] - 144s 387ms/step - loss: 0.3373 - accuracy: 0.8531 - val_loss: 0.2775 - val_accuracy: 0.9000
# Epoch 5/10
# 372/372 [==============================] - 144s 387ms/step - loss: 0.3214 - accuracy: 0.8595 - val_loss: 0.3042 - val_accuracy: 0.8900
# Epoch 6/10
# 372/372 [==============================] - 144s 386ms/step - loss: 0.2949 - accuracy: 0.8722 - val_loss: 0.2677 - val_accuracy: 0.9075
# Epoch 7/10
# 372/372 [==============================] - 144s 386ms/step - loss: 0.3086 - accuracy: 0.8696 - val_loss: 0.8210 - val_accuracy: 0.7525
# Epoch 8/10
# 372/372 [==============================] - 144s 387ms/step - loss: 0.2617 - accuracy: 0.8910 - val_loss: 0.2305 - val_accuracy: 0.9225
# Epoch 9/10
# 372/372 [==============================] - 144s 388ms/step - loss: 0.2064 - accuracy: 0.9162 - val_loss: 0.2618 - val_accuracy: 0.9025
# Epoch 10/10
# 372/372 [==============================] - 144s 387ms/step - loss: 0.1765 - accuracy: 0.9297 - val_loss: 0.2215 - val_accuracy: 0.9200
# Best model for HSV color space saved as best_model_HSV.keras
# Training model for LAB color space...
# Epoch 1/10
# 372/372 [==============================] - 146s 391ms/step - loss: 0.6732 - accuracy: 0.7240 - val_loss: 0.4477 - val_accuracy: 0.7400
# Epoch 2/10
# 372/372 [==============================] - 145s 390ms/step - loss: 0.4249 - accuracy: 0.7886 - val_loss: 0.3753 - val_accuracy: 0.8100
# Epoch 3/10
# 372/372 [==============================] - 145s 390ms/step - loss: 0.3788 - accuracy: 0.8242 - val_loss: 0.3957 - val_accuracy: 0.8000
# Epoch 4/10
# 372/372 [==============================] - 145s 390ms/step - loss: 0.3525 - accuracy: 0.8422 - val_loss: 0.2890 - val_accuracy: 0.8925
# Epoch 5/10
# 372/372 [==============================] - 144s 388ms/step - loss: 0.3108 - accuracy: 0.8686 - val_loss: 0.2389 - val_accuracy: 0.9150
# Epoch 6/10
# 372/372 [==============================] - 144s 388ms/step - loss: 0.2783 - accuracy: 0.8795 - val_loss: 0.2684 - val_accuracy: 0.8900
# Epoch 7/10
# 372/372 [==============================] - 143s 386ms/step - loss: 0.2534 - accuracy: 0.8952 - val_loss: 0.2693 - val_accuracy: 0.8875
# Epoch 8/10
# 372/372 [==============================] - 143s 384ms/step - loss: 0.2031 - accuracy: 0.9178 - val_loss: 0.2166 - val_accuracy: 0.9325
# Epoch 9/10
# 372/372 [==============================] - 143s 385ms/step - loss: 0.1706 - accuracy: 0.9316 - val_loss: 0.2282 - val_accuracy: 0.9250
# Epoch 10/10
# 372/372 [==============================] - 143s 384ms/step - loss: 0.1360 - accuracy: 0.9447 - val_loss: 0.1928 - val_accuracy: 0.9350
# Best model for LAB color space saved as best_model_LAB.keras
# Training model for YCbCr color space...
# Epoch 1/10
# 372/372 [==============================] - 149s 400ms/step - loss: 1.1570 - accuracy: 0.7670 - val_loss: 0.4387 - val_accuracy: 0.7250
# Epoch 2/10
# 372/372 [==============================] - 163s 438ms/step - loss: 0.3986 - accuracy: 0.8199 - val_loss: 0.3151 - val_accuracy: 0.8875
# Epoch 3/10
# 372/372 [==============================] - 145s 389ms/step - loss: 0.3733 - accuracy: 0.8345 - val_loss: 0.2810 - val_accuracy: 0.8900
# Epoch 4/10
# 372/372 [==============================] - 143s 384ms/step - loss: 0.3524 - accuracy: 0.8444 - val_loss: 0.2726 - val_accuracy: 0.9050
# Epoch 5/10
# 372/372 [==============================] - 142s 381ms/step - loss: 0.3254 - accuracy: 0.8572 - val_loss: 0.2510 - val_accuracy: 0.9200
# Epoch 6/10
# 372/372 [==============================] - 143s 383ms/step - loss: 0.3053 - accuracy: 0.8702 - val_loss: 0.2864 - val_accuracy: 0.9100
# Epoch 7/10
# 372/372 [==============================] - 142s 382ms/step - loss: 0.2868 - accuracy: 0.8741 - val_loss: 0.2751 - val_accuracy: 0.8975
# Epoch 8/10
# 372/372 [==============================] - 143s 383ms/step - loss: 0.2587 - accuracy: 0.8903 - val_loss: 0.2878 - val_accuracy: 0.8875
# Epoch 9/10
# 372/372 [==============================] - 143s 385ms/step - loss: 0.2291 - accuracy: 0.9050 - val_loss: 0.3057 - val_accuracy: 0.8750
# Epoch 10/10
# 372/372 [==============================] - 146s 393ms/step - loss: 0.1947 - accuracy: 0.9187 - val_loss: 0.2849 - val_accuracy: 0.9000
# Best model for YCbCr color space saved as best_model_YCbCr.keras
# Training model for Greyscale color space...
# Epoch 1/10
# 372/372 [==============================] - 147s 395ms/step - loss: 0.7069 - accuracy: 0.7107 - val_loss: 0.4921 - val_accuracy: 0.7775
# Epoch 2/10
# 372/372 [==============================] - 146s 391ms/step - loss: 0.4797 - accuracy: 0.7656 - val_loss: 0.5236 - val_accuracy: 0.6675
# Epoch 3/10
# 372/372 [==============================] - 144s 387ms/step - loss: 0.4428 - accuracy: 0.7846 - val_loss: 0.3549 - val_accuracy: 0.8425
# Epoch 4/10
# 372/372 [==============================] - 144s 386ms/step - loss: 0.3994 - accuracy: 0.8108 - val_loss: 0.3446 - val_accuracy: 0.8625
# Epoch 5/10
# 372/372 [==============================] - 150s 403ms/step - loss: 0.5860 - accuracy: 0.7713 - val_loss: 0.4130 - val_accuracy: 0.8025
# Epoch 6/10
# 372/372 [==============================] - 152s 408ms/step - loss: 0.4110 - accuracy: 0.8000 - val_loss: 0.3535 - val_accuracy: 0.8600
# Epoch 7/10
# 372/372 [==============================] - 142s 381ms/step - loss: 0.3368 - accuracy: 0.8451 - val_loss: 0.3311 - val_accuracy: 0.8450
# Epoch 8/10
# 372/372 [==============================] - 142s 382ms/step - loss: 0.3013 - accuracy: 0.8599 - val_loss: 0.3251 - val_accuracy: 0.8600
# Epoch 9/10
# 372/372 [==============================] - 148s 398ms/step - loss: 0.2624 - accuracy: 0.8827 - val_loss: 0.2791 - val_accuracy: 0.8850
# Epoch 10/10
# 372/372 [==============================] - 142s 383ms/step - loss: 0.2328 - accuracy: 0.8973 - val_loss: 0.2865 - val_accuracy: 0.8800
# Best model for Greyscale color space saved as best_model_Greyscale.keras

# %%
from tensorflow.keras.models import load_model

models = {}
for color_space in ColorSpace:
    model_path = f'best_model_{color_space.value}.keras'
    models[color_space.value] = load_model(model_path)

# %%
models
# Out:
# {'BGR': <keras.src.engine.sequential.Sequential at 0x352b65540>,
#  'HSV': <keras.src.engine.sequential.Sequential at 0x3d11df220>,
#  'LAB': <keras.src.engine.sequential.Sequential at 0x3d11dd810>,
#  'YCbCr': <keras.src.engine.sequential.Sequential at 0x3d11f5990>,
#  'Greyscale': <keras.src.engine.sequential.Sequential at 0x3d1237a60>}

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

metrics_df = pd.DataFrame(columns=['Model', 'Accuracy', 'Precision', 'Recall', 'F1'])
metrics_list = []

threshold = 0.5
individual_preds = {}
for color_space, model in models.items():
    test_sequence = SkinLesionDataSequence(base_dir='data', dataset_type=DatasetType.Test, color_space=ColorSpace(color_space), batch_size=batch_size, normalize=True)
    true_labels = test_sequence.labels
    preds = model.predict(test_sequence)
    individual_preds[color_space] = (preds > threshold).astype(int)

    # Calculate metrics for individual model
    acc = accuracy_score(true_labels, individual_preds[color_space].flatten())
    prec = precision_score(true_labels, individual_preds[color_space].flatten())
    rec = recall_score(true_labels, individual_preds[color_space].flatten())
    f1 = f1_score(true_labels, individual_preds[color_space].flatten())

    metrics_list.append({'Model': color_space, 'Accuracy': acc, 'Precision': prec, 'Recall': rec, 'F1': f1})
# Out:
# 50/50 [==============================] - 6s 112ms/step
# 50/50 [==============================] - 5s 109ms/step
# 50/50 [==============================] - 6s 110ms/step
# 50/50 [==============================] - 5s 109ms/step
# 50/50 [==============================] - 5s 109ms/step

# %%
# Simple average ensemble
ensemble_preds = np.mean(list(individual_preds.values()), axis=0)
final_ensemble_preds = np.where(ensemble_preds > threshold, 1, 0).flatten()

ensemble_acc = accuracy_score(true_labels, final_ensemble_preds)
ensemble_prec = precision_score(true_labels, final_ensemble_preds)
ensemble_rec = recall_score(true_labels, final_ensemble_preds)
ensemble_f1 = f1_score(true_labels, final_ensemble_preds)

metrics_list.append({'Model': 'Ensemble', 'Accuracy': ensemble_acc, 'Precision': ensemble_prec, 'Recall': ensemble_rec, 'F1': ensemble_f1})
metrics_df = pd.DataFrame(metrics_list)

# %%
# Bayesian Model Averaging Ensemble
weights = [metrics['Accuracy'] for metrics in metrics_list[:-1]]  # Exclude Ensemble from metrics_list
total_weight = sum(weights)
normalized_weights = [w / total_weight for w in weights]

prepared_preds = [pred.squeeze() for pred in individual_preds.values()]

bma_preds = np.average(prepared_preds, axis=0, weights=normalized_weights)
final_bma_preds = np.where(bma_preds > threshold, 1, 0).flatten()

bma_metrics = {
    'Model': 'Bayesian Model Averaging',
    'Accuracy': accuracy_score(true_labels, final_bma_preds),
    'Precision': precision_score(true_labels, final_bma_preds),
    'Recall': recall_score(true_labels, final_bma_preds),
    'F1': f1_score(true_labels, final_bma_preds)
}

bma_df = pd.DataFrame([bma_metrics])

metrics_df = pd.concat([metrics_df, bma_df], ignore_index=True)
metrics_df
# Out:
#                       Model  Accuracy  Precision   Recall        F1
# 0                       BGR  0.896250   0.861048  0.94500  0.901073
# 1                       HSV  0.902500   0.875291  0.93875  0.905911
# 2                       LAB  0.914375   0.915935  0.91250  0.914214
# 3                     YCbCr  0.890000   0.865340  0.92375  0.893591
# 4                 Greyscale  0.872500   0.875315  0.86875  0.872020
# 5                  Ensemble  0.925000   0.905728  0.94875  0.926740
# 6  Bayesian Model Averaging  0.925000   0.905728  0.94875  0.926740

# %% [markdown]
# ## Results
# Same results for plain average ensemble and Bayesian Model Averaging.
